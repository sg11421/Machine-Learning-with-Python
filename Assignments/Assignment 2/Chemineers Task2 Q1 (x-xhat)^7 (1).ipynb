# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
x = 2 * np.random.rand(100, 1)
y = 4 + 3 * x + np.random.randn(100, 1)
plt.scatter(x, y)
m=x.shape[0]

# %%
def cost(y_hat, y):
    l = (np.abs(y_hat-y))**3
    cost = np.mean(l)
    return cost

# %%
def hypothesis(x, w, b):
    return np.multiply(x, w) + b

# %%
def gradient_descent(x, y, w, b, learning_rate, m):
    y_hat = hypothesis(x, w, b)
    dw = (7.0/m) * np.sum(np.multiply(x,((y_hat-y)**6)))
    db = (7.0/m) * np.sum((y_hat-y)**6)
    w = w -learning_rate * dw
    b = b - learning_rate * db
    return w,b

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# def find_best_learning_rate(x, y, num_epochs=10000, learning_rates=[0.1,0.0000000001]):
#     m = len(x)
#     w = np.random.randn(1) * 0.01
#     b = np.random.randn(1) * 0.01

#     best_lr = None
#     best_loss = float('inf')

#     for lr in learning_rates:
#         w, b = np.random.randn(1) * 0.01, np.random.randn(1) * 0.01
#         for epoch in range(num_epochs):
#             y_hat = hypothesis(x, w, b)
#             dw = (3.0 / m) * np.sum(np.multiply(x, (y_hat - y) ** 2))
#             db = (3.0 / m) * np.sum((y_hat - y) ** 2)
#             w = w - lr * dw
#             b = b - lr * db

#         y_hat = hypothesis(x, w, b)
#         current_loss = cost(y_hat, y)

#         if current_loss < best_loss:
#             best_loss = current_loss
#             best_lr = lr

#     return best_lr

# # Example usage
# best_learning_rate = find_best_learning_rate(x, y)
# print(f"Best learning rate: {best_learning_rate}")
# Out:
#   Cell In[15], line 4
#     def find_best_learning_rate(x, y, num_epochs=10000, learning_rates=[0.1:0.0000000001]):
#                                                                            ^
# SyntaxError: invalid syntax

# %%
# Random Initialisation
w = np.random.randn(1)*0.000001
b = np.random.randn(1)*0.000001

# Hyperparameters
learning_rate = 0.0000000000030
num_epochs = 100000

L=[]
for i in range(num_epochs):
    w, b = gradient_descent(x,y,w,b,learning_rate, m)
    y_hat = hypothesis(x,w,b)
    L.append(cost(y_hat,y))
    if (i%(num_epochs/10))==0:
        plt.plot(x,y,'bo')
        plt.plot(x,y_hat,'g--')
        plt.show()

# %%
print(f"Obtained value of w: {w}")
print(f"Obtained value of b: {b}")
print(f"Obtained line: y={w}x+{b}")
plt.plot(x,y,'bo')
plt.plot(x,y_hat,'g--')
plt.show()
# Out:
# Obtained value of w: [-5.33946771]
# Obtained value of b: [-3.32193246]
# Obtained line: y=[-5.33946771]x+[-3.32193246]

# %%
plt.plot(L,'r')
plt.show()
