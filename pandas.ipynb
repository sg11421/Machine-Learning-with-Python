# %%
import numpy as np 
import pandas as pd

# %%
dict1={
    "name":['harry','rohan','skillf','shubh'],
    "marks":[92,34,24,17],
    "city":['rampur','kolkata','bareily','antarctica']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24     bareily
# 3   shubh     17  antarctica

# %%
df.to_csv('friends.csv',index=False)

# %%
df.head(3)
# Out:
#      name  marks     city
# 0   harry     92   rampur
# 1   rohan     34  kolkata
# 2  skillf     24  bareily

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
harshit=pd.read_csv('friends.csv')

# %%
harshit
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24     bareily
# 3   shubh     17  antarctica

# %%
harshit['marks']
# Out:
# 0    92
# 1    34
# 2    24
# 3    17
# Name: marks, dtype: int64

# %%
harshit['marks'][0]=50
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_25360\1757368225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harshit['marks'][0]=50

# %%
harshit['marks']
# Out:
# 0    50
# 1    34
# 2    24
# 3    17
# Name: marks, dtype: int64

# %%
harshit.index=[1,2,3,4,5,6]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 harshit.index=[1,2,3,4,5,6]
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 6 elements

# %%
harshit
# Out:
#       name  marks        city
# 1    harry     50      rampur
# 2    rohan     34     kolkata
# 3   skillf     24     bareily
# 4    shubh     17  antarctica
# 5  harshit     67    varanasi
# 6  durgesh     89    varanasi

# %%
ser=pd.Series(np.random.rand(34))

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.199515  0.271079  0.163674  0.410329  0.908803
# 1    0.372495  0.675951  0.875314  0.259461  0.476183
# 2    0.143896  0.152048  0.770125  0.396312  0.068564
# 3    0.125672  0.348081  0.474019  0.004762  0.272213
# 4    0.710691  0.178162  0.835101  0.224945  0.621880
# ..        ...       ...       ...       ...       ...
# 329  0.545111  0.804697  0.105610  0.332008  0.295245
# 330  0.435082  0.976170  0.007041  0.025298  0.279858
# 331  0.657746  0.427831  0.289128  0.083757  0.652358
# 332  0.940642  0.568419  0.628861  0.302367  0.243457
# 333  0.585747  0.630843  0.643127  0.296420  0.470598
#
# [334 rows x 5 columns]

# %%
type(newdf)
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.199515  0.271079  0.163674  0.410329  0.908803
# 1  0.372495  0.675951  0.875314  0.259461  0.476183
# 2  0.143896  0.152048  0.770125  0.396312  0.068564
# 3  0.125672  0.348081  0.474019  0.004762  0.272213
# 4  0.710691  0.178162  0.835101  0.224945  0.621880

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,'A']=65456

# %%
newdf
# Out:
#             A         B         C         D         E
# 0       65456  0.271079  0.163674  0.410329  0.908803
# 1    0.372495  0.675951  0.875314  0.259461  0.476183
# 2    0.143896  0.152048  0.770125  0.396312  0.068564
# 3    0.125672  0.348081  0.474019  0.004762  0.272213
# 4    0.710691  0.178162  0.835101  0.224945  0.621880
# ..        ...       ...       ...       ...       ...
# 329  0.545111  0.804697  0.105610  0.332008  0.295245
# 330  0.435082  0.976170  0.007041  0.025298  0.279858
# 331  0.657746  0.427831  0.289128  0.083757  0.652358
# 332  0.940642  0.568419  0.628861  0.302367  0.243457
# 333  0.585747  0.630843  0.643127  0.296420  0.470598
#
# [334 rows x 5 columns]

# %%
newdf.drop('E',axis=1)
# Out:
#             A         B         C         D
# 0       65456  0.271079  0.163674  0.410329
# 1    0.372495  0.675951  0.875314  0.259461
# 2    0.143896  0.152048  0.770125  0.396312
# 3    0.125672  0.348081  0.474019  0.004762
# 4    0.710691  0.178162  0.835101  0.224945
# ..        ...       ...       ...       ...
# 329  0.545111  0.804697  0.105610  0.332008
# 330  0.435082  0.976170  0.007041  0.025298
# 331  0.657746  0.427831  0.289128  0.083757
# 332  0.940642  0.568419  0.628861  0.302367
# 333  0.585747  0.630843  0.643127  0.296420
#
# [334 rows x 4 columns]

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.875314  0.259461
# 2  0.770125  0.396312

# %%
newdf.loc[[1,2,3,4,5],:]
# Out:
#           A         B         C         D         E
# 1  0.372495  0.675951  0.875314  0.259461  0.476183
# 2  0.143896  0.152048  0.770125  0.396312  0.068564
# 3  0.125672  0.348081  0.474019  0.004762  0.272213
# 4  0.710691  0.178162  0.835101  0.224945  0.621880
# 5  0.227568  0.415665  0.508813  0.924340  0.442742

# %%
newdf.loc[(newdf[[2],axis=0]<0.3)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 newdf.loc[(newdf[[2],axis==0]<0.3)]
#
# NameError: name 'newdf' is not defined

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0     65456  0.271079  0.163674  0.410329  0.908803
# 1  0.372495  0.675951  0.875314  0.259461  0.476183
# 2  0.143896  0.152048  0.770125  0.396312  0.068564
# 3  0.125672  0.348081  0.474019  0.004762  0.272213
# 4  0.710691  0.178162  0.835101  0.224945  0.621880

# %%
newdf.iloc[0,4]
# Out:
# 0.908802675107919

# %%
newdf.iloc[[2,3],[2,3]]
# Out:
#           C         D
# 2  0.770125  0.396312
# 3  0.474019  0.004762

# %%
newdf.drop(['A','C'],axis=1)
# Out:
#             B         D         E
# 0    0.271079  0.410329  0.908803
# 1    0.675951  0.259461  0.476183
# 2    0.152048  0.396312  0.068564
# 3    0.348081  0.004762  0.272213
# 4    0.178162  0.224945  0.621880
# ..        ...       ...       ...
# 329  0.804697  0.332008  0.295245
# 330  0.976170  0.025298  0.279858
# 331  0.427831  0.083757  0.652358
# 332  0.568419  0.302367  0.243457
# 333  0.630843  0.296420  0.470598
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,2],axis=0)
# Out:
#             A         B         C         D         E
# 0       65456  0.271079  0.163674  0.410329  0.908803
# 3    0.125672  0.348081  0.474019  0.004762  0.272213
# 4    0.710691  0.178162  0.835101  0.224945  0.621880
# 5    0.227568  0.415665  0.508813  0.924340  0.442742
# 6    0.300387  0.274849  0.015036  0.344693  0.238849
# ..        ...       ...       ...       ...       ...
# 329  0.545111  0.804697  0.105610  0.332008  0.295245
# 330  0.435082  0.976170  0.007041  0.025298  0.279858
# 331  0.657746  0.427831  0.289128  0.083757  0.652358
# 332  0.940642  0.568419  0.628861  0.302367  0.243457
# 333  0.585747  0.630843  0.643127  0.296420  0.470598
#
# [332 rows x 5 columns]

# %%
newdf.drop([2,4,5],axis=0,inplace=True)

# %%
newdf
# Out:
#             A         B         C         D         E
# 