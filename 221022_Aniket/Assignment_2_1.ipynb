# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket221022/Machine-Learning-with-Python/blob/main/Assignment_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate random data
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 2 * X + 1 + np.random.randn(100, 1) * 2  # Adding some noise to the data

# Create a DataFrame
data = pd.DataFrame({'X': X.flatten(), 'y': y.flatten()})

# %%
# Gradient descent
learning_rate = 0.01
n_iterations = 1000
m = 100

for iteration in range(n_iterations):
    error = X_b.dot(theta) - y
    gradients = 2/m * X_b.T.dot(error * np.sign(error) * np.abs(error) ** 2)
    theta = theta - learning_rate * gradients

# Plot the linear regression curve
plt.scatter(X, y)
plt.plot(X, X_b.dot(theta), color='r', label='Custom Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# <ipython-input-11-1f217980eb7c>:8: RuntimeWarning: overflow encountered in square
#   gradients = 2/m * X_b.T.dot(error * np.sign(error) * np.abs(error) ** 2)

# %%
# Gradient descent for polynomial regression
learning_rate = 0.01
n_iterations = 1000
m = 100

# Initialize theta_poly with the correct dimensions
theta_poly = np.random.randn(X_poly.shape[1], 1)

for iteration in range(n_iterations):
    error_poly = X_poly.dot(theta_poly) - y
    gradients_poly = 2/m * X_poly.T.dot(error_poly * np.sign(error_poly) * np.abs(error_poly) ** 6)
    theta_poly = theta_poly - learning_rate * gradients_poly

# Plot the polynomial regression curve
plt.scatter(X, y)
plt.plot(X, X_poly.dot(theta_poly), color='g', label='Custom Polynomial Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# <ipython-input-14-009cd853d5e4>:11: RuntimeWarning: overflow encountered in power
#   gradients_poly = 2/m * X_poly.T.dot(error_poly * np.sign(error_poly) * np.abs(error_poly) ** 6)
# <ipython-input-14-009cd853d5e4>:11: RuntimeWarning: overflow encountered in multiply
#   gradients_poly = 2/m * X_poly.T.dot(error_poly * np.sign(error_poly) * np.abs(error_poly) ** 6)

# %%
from sklearn.linear_model import LinearRegression

# Create and fit a linear regression model using scikit-learn
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Plot the linear regression curve using scikit-learn
plt.scatter(X, y)
plt.plot(X, lin_reg.predict(X), color='b', label='Scikit-learn Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Plot all curves in the same figure
plt.scatter(X, y)
plt.plot(X, X_b.dot(theta), color='r', label='Custom Linear Regression')
plt.plot(X, X_poly.dot(theta_poly), color='g', label='Custom Polynomial Regression')
plt.plot(X, lin_reg.predict(X), color='b', label='Scikit-learn Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
